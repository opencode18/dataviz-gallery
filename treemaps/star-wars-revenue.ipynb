# %%
import pandas as pd
import squarify
import matplotlib
from matplotlib import style
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (16.0, 9.0)
#style.use('fivethirtyeight')

# %%
df = pd.read_csv("starwars-revenue.csv")
df = df.sort_values(by="Revenue", ascending=False)
df["Percentage"] = round(100 * df["Revenue"] / sum(df["Revenue"]), 2)
df["Label"] = df["Label"] + " (" + df["Percentage"].astype("str") + "%)"
df
# Out:
#                               Movie     Revenue                         Label  \
# 6     Episode 7 – The Force Awakens  4068223624    The Force Awakens (37.68%)
# 7                         Rogue One  2450000000            Rogue One (22.69%)
# 0    Episode 1 – The Phantom Menace   924317558    The Phantom Menace (8.56%)
# 2   Episode 3 – Revenge of the Sith   848754768   Revenge of the Sith (7.86%)
# 3            Episode 4 – A New Hope   775398007            A New Hope (7.18%)
# 1  Episode 2 – Attack of the Clones   649398328  Attack of the Clones (6.01%)
# 4   Episode 5 – Empire Strikes Back   538375067   Empire Strikes Back (4.99%)
# 5    Episode 6 – Return of the Jedi   475106177     Return of the Jedi (4.4%)
# 8                    The Clone Wars    68282844        The Clone Wars (0.63%)
#
#    Percentage
# 6       37.68
# 7       22.69
# 0        8.56
# 2        7.86
# 3        7.18
# 1        6.01
# 4        4.99
# 5        4.40
# 8        0.63

# %%
fig, ax = plt.subplots()
cmap = matplotlib.cm.coolwarm
mini = min(df["Revenue"])
maxi = max(df["Revenue"])
norm = matplotlib.colors.Normalize(vmin=mini, vmax=maxi)
colors = [cmap(norm(value)) for value in df["Revenue"]]
squarify.plot(sizes=df["Revenue"], label=df["Label"], alpha=0.8, color=colors)
plt.axis('off')
plt.gca().invert_yaxis()
plt.title("Revenue from Star Wars Franchise Movies", fontsize=32)
ttl = ax.title
ttl.set_position([.5, 1.05])
fig.set_facecolor('#eeffee')
